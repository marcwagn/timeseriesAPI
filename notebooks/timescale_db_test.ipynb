# %%
DATABASE_URL = (
    "postgresql+asyncpg://postgres:password@localhost:5432"
)

# %%
from sqlalchemy.ext.asyncio import create_async_engine

engine = create_async_engine(
    DATABASE_URL,
    echo=True,
)

# %%
from sqlalchemy.ext.asyncio import AsyncSession
from sqlalchemy.orm import sessionmaker

AsyncSessionLocal = sessionmaker(
    bind=engine,
    class_=AsyncSession,
    expire_on_commit=False,
)

# %%
from sqlalchemy import text

async with engine.connect() as conn:
    result = await conn.execute(text("SELECT * FROM conditions;"))
    print(result.all())
    #print(result.scalar())
# Out:
# 2026-01-24 21:21:14,877 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-24 21:21:14,878 INFO sqlalchemy.engine.Engine SELECT * FROM conditions;
# 2026-01-24 21:21:14,878 INFO sqlalchemy.engine.Engine [cached since 22.94s ago] ()
# [(datetime.datetime(2026, 1, 18, 20, 38, 50, 665280, tzinfo=datetime.timezone.utc), 'office', 70.0, 50.0), (datetime.datetime(2026, 1, 18, 20, 38, 50, 665280, tzinfo=datetime.timezone.utc), 'basement', 66.5, 60.0), (datetime.datetime(2026, 1, 18, 20, 38, 50, 665280, tzinfo=datetime.timezone.utc), 'garage', 77.0, 65.2)]
# 2026-01-24 21:21:14,880 INFO sqlalchemy.engine.Engine ROLLBACK
